# %% [markdown]
# <a href="https://colab.research.google.com/github/Duncan-Haywood/affirmations_chatbot/blob/master/therapy_chatbot_v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## a storage of all the questions asked and answers
conversation = []

# %%
## module imports
import random
# import json
journal_question_list = [
"What is something that went well in your day today?", 
"What is something you can do today to bring yourself joy?", 
"What are you grateful for today?", 
"What is something beautiful you saw today? ", 
"What is something you can do today to bring yourself joy?", 
"What made you smile today? ", 
"How can you give love to your inner child today?", 
"In your day-to-day activities what is one activity during which you can practice smiling?", 
"What act of kindness can you give to someone right now?", 
"If your belly were a person, what would it say to you right now? ", 
"If you had unlimited resources and time what is something big you can do for someone? You can be creative here.",
"What would make today worthwhile?",
"What is your daily affirmation today",
"What is is something you did today that you can improve upon tomorrow?",
"What is a big career impact you would like to have on the world?",
"What is a spiritual goal of yours?",
"For whom can you do an act of service today?",
"What is a dream act of service for you to give somebody?",
"What would the rules be if you created rules for your entire life?"
"What piece of advice would you give yourself?",
"What words would you like to live by?",
"When you are in pain, what is the kindest thing you can do for yourself?",
"What would you do if you loved yourself unconditionally?",
"What is enough for you?",
"If your belly is a person, what does it say?",
"What are the questions to which you urgently need answers?",
"What can you learn about to help you live a more fulfilling life?",
"What words do you need to hear?",
"What don't you want to write about?"
"Who are you now?",
"What experiences would have the most positive impact on your life?",
"Who do you spend the most time with? What is their impact on you?",
"Who do you admire? What do you admire in them?",
"What is one of the most painful experiences of your life? What have you learned from this experience?",
"What would you do if you didn't need to consider money or the opinions of others?",
"What do you do that brings you suffering? How can you improve this?",
"How do you spend your time? How do you spend your money?",
"What is your ideal budger using percentages? ie. 10% dance, 10% dining, ...",
"What is a book you wish someone would write?",
"Define the following: Success. Wisdom. Love. Faith. Truth. Courage. Joy. Happiness."
"Who would you like to be? What would you like to do? How would you like to feel in these roles?",
"Imagine the life you wish to live. How does this feel? What are you doing?",
"What can you do better tomorrow if you live today again exactly?",
"If your throat is a person, what does it say?",
"What feels important to you right now?",
"How can you give love to the child that you are?",
"What are your intentions for the rest of the day?",
"Who is your highest self?",
"What act of kindness have you recently given to another person?",
"What act of kindness have you recently given to yourself?",
"What would the rules be if you created the rules for humanity?",
"Who is a role model of yours? What qualities do you admire in them?",
"What are you grateful for?",
"What are you looking forward to?",
"What made you smile today?", 
"What made you laugh today?",
"What made today a good day?",
"What made today awesome?",
"What was the best thing that happened to you today?",
"What's something kind someone did for you today?",
"What made today special?"
]

gratitude_question_list = [
"What are you grateful for today?",
"Who has improved your day today?",
"Who is someone you admire? What are some of their good qualities?",
"Who is someone of whom you are proud? What are you proud of them for?" 
##the second part is a good followup question
]

# %%
## To use click the play button to the left of this box and scroll to the bottom :)


## prints a leading phrase to introduce a question or request
def question_prompt():
  question_prompts = [
  "May I ask,", 
  "I'm wondering,", 
  "I'm curious,", 
  "Would you do me the kindness of telling me,", 
  "I'd love to know,",
  "I would enjoy knowing,"
  ]

  i = random.randint(0,len(question_prompts)-1)
  q_prompt = question_prompts[i]
  print(q_prompt)

## returns thankful praise for use of the program as the user answers.
def gratitude_for_use():
  grateful_phrases = [
  "Good job answering.",
  "You're doing a wonderful job caring for yourself.",
  "You are improving the lives of those around you.",
  "I appreciate you taking the time to help out this project.",
  "Your answers will help us create more caring conversations\
  \nfor yourself and others! :)",
  "You are doing great!",
  "You are helping us think better. Thank you!",
  "You matter <3",
  "You are perfect exactly as you are.",
  "I love you.",
  "Thank you for helping us out with this project",
  "I love when do such a wonderful job answering!",
  "Thank you! :)",
  "You have worth.",
  "I appreciate you.",
  "Great job!",
  "Aww <3 That's nice. :)",
  "You delight me <3"
  ]
  i = random.randint(0,len(grateful_phrases)-1)
  g_phrase = grateful_phrases[i]
  print("\n" + g_phrase + "\n")
  pass


## Introduce the program to the user
def intro():
  print("If there are any questions you would not like to answer, \
  \nplease write \"pass\" and it will move to the next question.\n")


## prompts a question and  
## saves (appends) the question and the answer to the answers file
def add_answer(question):
  answer = input(question + "\n")
  
	# with open('answers.json', 'a') as answers:
  #   json.dump(answers, [question, answer])
  conversation.append((question, answer))
  return answer


## Asks a question from the question list and returns answer
def run_main_question(question_list):
  print("")
  i = random.randint(0, len(question_list)-1)
  question = question_list[i]
  answer = add_answer(question)
  gratitude_for_use()
  return question, answer

## asks the user to ask themselves a follow up question
def run_followup_q(question):
  followup_question = input("\
  \nWould you like to be asked a followup question?\
  \nIf so, what would you like to be asked?\n")
  if followup_question.lower() == 'pass':
    return
  gratitude_for_use()
  print("")
  question_prompt()
  answer = add_answer(followup_question)
  q_followup = (question, followup_question, answer)
  conversation.append(q_followup)
  gratitude_for_use()
  # with open(followup_questions.json, 'a') as followup_questions:
  #   json.dump(q_followup, followup_questions)


  

def run_new_question():
  print("")
  new_q_prompt = "What question would you like to be asked by me?"
  new_q = add_answer(new_q_prompt)
  gratitude_for_use()
  print("")
  if new_q.lower() == 'pass':
    return
  
  question_prompt()
  answer = add_answer(new_q)
  gratitude_for_use()
  return question, answer

def improvement_prompt():
    print("")
    improvement_question = "Is there anything you would like us to improve?"
    improvement= add_answer(improvement_question)
    gratitude_for_use()
    print("")
    
def affirmation_prompt():
  question = "What words would you most like to hear from me right now?"
  answer = add_answer(question)
  print("")
  print(answer)
  gratitude_for_use()
  gratitude_for_use()
  gratitude_for_use()

# runs the file, giving instructions, deciding which list to choose, 
# asking question, retrieving followup question, asking follow up question, 
# and storing these together
def run():
  intro()
  question_list = gratitude_question_list
  while True:
    for i in range(3):
      improvement_prompt()
      affirmation_prompt()
      ## needs fixing because is being returned none type which is not iterable
      # question, answer = run_main_question(question_list)
      if answer.lower() != 'pass':
        run_followup_q(question)
      question, answer = run_new_question()
      if answer.lower() != 'pass':
        run_followup_q(question)
      
      
      # run_values_question()
      # run_virtue_affirmation()





run()
# Out:
# If there are any questions you would not like to answer,
# please write "pass" and it will move to the next question.
#
#
# Is there anything you would like us to improve?
# pass
#
# I appreciate you.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
# ...

# %%
conversation
# Out:
# [('Who has improved your day today?',
#   'Joel has gifted me with his kind words; he tells me frequently with grace, "Duncan, you do well to me; you are magical."'),
#  ('What words would you most like to hear from me right now?',
#   'I would love to hear from you, "Duncan, you are a wonderful human being, and I support you. I love you. May you be filled by the small joys all around you."'),
#  ('What words would you most like to hear from me right now?', 'I love you'),
#  ('What words would you most like to hear from me right now?',
#   'You are perfect exactly as you are'),
#  ('What are you grateful for today?', 'pass'),
#  ('What question would you like to be asked by me?', 'pass'),
#  ('Is there anything you would like us to improve?',
#   'I would love to see you all improve the flexibility of which types of questions to answer. A UI would be great'),
#  ('Is there anything you would like us to improve?',
#   'You all just did a great job fixing a bug.'),
# ...

# %%
duncan_conversation = [('If your belly is a person, what does it say?',
  'It says I could use some better nutrition. Also, I feel pretty good today. '),
 ('When you are in pain, what is the kindest thing you can do for yourself?',
  'I can smile, listen to my pain, and breathe deeply.'),
 ('What act of kindness have you recently given to yourself?',
  'I have been speaking with people who fill me with joy.'),
 ('What made you laugh today?',
  'Listening to someone who was laughing themselves'),
 ('What feels important to you right now?',
  'Creating a pleasant experience for my users of this interface.'),
 ('What made today awesome?',
  'Today is awsome because I have beautiful music, cool breeze, warm breeze, a headwrap to keep me nice and pale, Beautiful woman to admire, friendly kind loving sweet souls to share time with. '),
 ('What is it about beautiful women you admire?', 'pass'),
 (None, 'What is it about beautiful women you admire?', 'pass'),
 ('What is one of the most painful experiences of your life? What have you learned from this experience?',
  'pass'),
 ('In your day-to-day activities what is one activity during which you can practice smiling?',
  'pass'),
 ('What is is something you did today that you can improve upon tomorrow?',
  'pass'),
 ('What is something you can do today to bring yourself joy?',
  'I can smile right now'),
 ('What experiences would have the most positive impact on your life?',
  'pass'),
 ('What would make today worthwhile?', 'Completing this single line of code.'),
 ('What benefit will arise from writing this line of code?',
  'I create a database of kind speech patterns to better socialize with others.'),
 ('What would make today worthwhile?',
  'What benefit will arise from writing this line of code?',
  'I create a database of kind speech patterns to better socialize with others.'),
 ('What made you smile today? ', 'pass'),
 ('What are your intentions for the rest of the day?',
  'I intend to go with how I feel in each moment and to listen to my highest desires, wishes, instinct, intuition.'),
 ('What are the questions to which you urgently need answers?',
  "I think I'm all set."),
  ('What made today special?',
  "I shared conversations with several wonderful people: Giselle, Keith, Vannia, and Keifer! It's also beautiful outside, and just my type of weather. "),
 ('In your day-to-day activities what is one activity during which you can practice smiling?',
  "I can practice smiling during listening to Terry Pratchet's book."),
  ("What's something kind someone did for you today?", 'pass'),
 ('What question would you like to be asked by me?', 'pass'),
 ('What words do you need to hear?',
  'I would love to hear, "you are special. I love you. You bring me great joy by practicing your bubbliness. I admire you for this. Well done." I am told these things and more by the people with whom I spend time. I am blessed to be around such wonderful people.'),
 ('Well done in practicing bubbliness. I see you giving others light in their lives. I admire your gratitude and praise of others too. I think you are doing a great job beginning to focus more on other people.',
  'pass'),
 ('What words do you need to hear?',
  'Well done in practicing bubbliness. I see you giving others light in their lives. I admire your gratitude and praise of others too. I think you are doing a great job beginning to focus more on other people.',
  'pass'),
 ('What question would you like to be asked by me?',
  'Who is someone around you that could use some love?'),
 ('Who is someone around you that could use some love?',
  'I reflexively say everybody; this is remaining in my own head amongst phrases I already hold. Nathan could use some love; I imagine he would enjoy being asked about his day. Gabby could use some love; she seems to enjoy a kind ear always; she seems to love spending time talking with people. Sue Ann could use some love; she seems to like spending time with her son. Gabrielle could use some praise for what she has been doing; (as a draft idea) she could also use a person who takes attentive interest in her as a human and aims to make her subjective experience more pleasurable. ')
  ('Who is someone you admire? What are some of their good qualities?',
  'I admire Tom; he does his best to support his children and create a thriving business for his work family.'),
 ('Who is someone you admire? What are some of their good qualities?',
  'I admire Tom, he tries his best always.'),
 ('Who has improved your day today?',
  'Joel, he shared his singing and joy, and creativity with me.'),
 ('This prompt could use improvement.', 'pass'),
 ('Who has improved your day today?',
  'This prompt could use improvement.',
  'pass'),
 ('What question would you like to be asked by me?',
  'I would like to be asked, what can we do to make this a more enjoyable experience.'),
 ('I would like to be asked, what can we do to make this a more enjoyable experience.',
  'Hahaha. '),
  ('What are you grateful for today?',
  'I am grateful for my friends who support me and fill me with energy'),
  ('What question would you like to be asked by me?',
  "I would love to be asked by you what value does this project add to Duncan's life?"),
  ('Who has improved your day today?',
  'Joel has gifted me with his kind words; he tells me frequently with grace, "Duncan, you do well to me; you are magical."'),
 ('What words would you most like to hear from me right now?',
  'I would love to hear from you, "Duncan, you are a wonderful human being, and I support you. I love you. May you be filled by the small joys all around you."'),
 ('What words would you most like to hear from me right now?', 'I love you'),
 ('What words would you most like to hear from me right now?',
  'You are perfect exactly as you are'),
 ('What are you grateful for today?', 'pass'),
 ('What question would you like to be asked by me?', 'pass'),
 ('Is there anything you would like us to improve?',
  'I would love to see you all improve the flexibility of which types of questions to answer. A UI would be great'),
 ('Is there anything you would like us to improve?',
  'You all just did a great job fixing a bug.'),
 ('What words would you most like to hear from me right now?',
  'You are blessed and love. You are surrounded by people who love you. You create much value in the lives of those with whom you connect. '),
 ('Is there anything you would like us to improve?', 'pass')
 ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-ea24484b7437> in <module>()
#      52   'I reflexively say everybody; this is remaining in my own head amongst phrases I already hold. Nathan could use some love; I imagine he would enjoy being asked about his day. Gabby could use some love; she seems to enjoy a kind ear always; she seems to love spending time talking with people. Sue Ann could use some love; she seems to like spending time with her son. Gabrielle could use some praise for what she has been doing; (as a draft idea) she could also use a person who takes attentive interest in her as a human and aims to make her subjective experience more pleasurable. ')
#      53   ('Who is someone you admire? What are some of their good qualities?',
# ...
